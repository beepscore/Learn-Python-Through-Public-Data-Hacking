# %%
import pandas

# %%
potholes = pandas.read_csv('data/input/potholes.csv')

# %%
potholes
# Out:
#        CREATION DATE           STATUS COMPLETION DATE SERVICE REQUEST NUMBER  \
# 0         01/01/2011  Completed - Dup      01/03/2011            11-00002110
# 1         01/01/2011  Completed - Dup      01/03/2011            11-00002209
# 2         01/01/2011  Completed - Dup      01/03/2011            11-00002224
# 3         01/01/2011  Completed - Dup      01/03/2011            11-00002247
# 4         01/01/2011  Completed - Dup      01/03/2011            11-00002276
# 5         01/01/2011  Completed - Dup      01/03/2011            11-00002947
# 6         01/01/2011  Completed - Dup      01/03/2011            11-00003041
# 7         01/01/2011  Completed - Dup      01/03/2011            11-00003086
# 8         01/01/2011  Completed - Dup      01/03/2011            11-00003439
# 9         01/01/2011        Completed      01/03/2011            11-00002021
# 10        01/01/2011        Completed      01/03/2011            11-00002273
# ...

# %%
# potholes['ZIP'].value_counts()[:10]
